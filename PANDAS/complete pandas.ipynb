# %%
import pandas as pd

# %%
df=pd.read_csv("ratings.csv")

# %%
df
# Out:
#     Unnamed: 0  userId  movieId  rating   timestamp
# 0            0       1        2     3.5  1112486027
# 1            1       1       29     3.5  1112484676
# 2            2       1       32     3.5  1112484819
# 3            3       1       47     3.5  1112484727
# 4            4       1       50     3.5  1112484580
# ..         ...     ...      ...     ...         ...
# 95          95       1     2947     3.5  1112485580
# 96          96       1     2959     4.0  1094785698
# 97          97       1     2968     4.0  1112485825
# 98          98       1     3000     3.5  1112484569
# 99          99       1     3030     3.0  1112484548
#
# [100 rows x 5 columns]

# %%
df.shape
# Out:
# (100, 5)

# %%
df.describe()
# Out:
#        Unnamed: 0  userId      movieId      rating     timestamp
# count  100.000000   100.0   100.000000  100.000000  1.000000e+02
# mean    49.500000     1.0  1508.790000    3.710000  1.106998e+09
# std     29.011492     0.0   857.773136    0.334694  8.227096e+06
# min      0.000000     1.0     2.000000    3.000000  1.094786e+09
# 25%     24.750000     1.0  1086.750000    3.500000  1.094786e+09
# 50%     49.500000     1.0  1284.500000    3.500000  1.112485e+09
# 75%     74.250000     1.0  2173.250000    4.000000  1.112486e+09
# max     99.000000     1.0  3030.000000    4.500000  1.112486e+09

# %%
df.info
# Out:
# <bound method DataFrame.info of     Unnamed: 0  userId  movieId  rating   timestamp
# 0            0       1        2     3.5  1112486027
# 1            1       1       29     3.5  1112484676
# 2            2       1       32     3.5  1112484819
# 3            3       1       47     3.5  1112484727
# 4            4       1       50     3.5  1112484580
# ..         ...     ...      ...     ...         ...
# 95          95       1     2947     3.5  1112485580
# 96          96       1     2959     4.0  1094785698
# 97          97       1     2968     4.0  1112485825
# 98          98       1     3000     3.5  1112484569
# 99          99       1     3030     3.0  1112484548
#
# [100 rows x 5 columns]>

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0  userId  movieId  rating   timestamp
# 0           0       1        2       0  1112486027
# 1           1       1       29       0  1112484676
# 2           2       1       32       0  1112484819
# 3           3       1       47       0  1112484727
# 4           4       1       50       0  1112484580

# %%
df
# Out:
#     Unnamed: 0  userId  movieId  rating   timestamp
# 0            0       1        2     3.5  1112486027
# 1            1       1       29     3.5  1112484676
# 2            2       1       32     3.5  1112484819
# 3            3       1       47     3.5  1112484727
# 4            4       1       50     3.5  1112484580
# ..         ...     ...      ...     ...         ...
# 95          95       1     2947     3.5  1112485580
# 96          96       1     2959     4.0  1094785698
# 97          97       1     2968     4.0  1112485825
# 98          98       1     3000     3.5  1112484569
# 99          99       1     3030     3.0  1112484548
#
# [100 rows x 5 columns]

# %%
df["rating"].isnull().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
df.columns=df.columns.str.replace(" ","_")

# %%
df.columns
# Out:
# Index(['Unnamed:-0', 'userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
df.rename(columns={"Unnamed:-0":"index1"},inplace=True)

# %%
df
# Out:
#     Unnamed:-0  userId  movieId  rating   timestamp
# 0            0       1        2     3.5  1112486027
# 1            1       1       29     3.5  1112484676
# 2            2       1       32     3.5  1112484819
# 3            3       1       47     3.5  1112484727
# 4            4       1       50     3.5  1112484580
# ..         ...     ...      ...     ...         ...
# 95          95       1     2947     3.5  1112485580
# 96          96       1     2959     4.0  1094785698
# 97          97       1     2968     4.0  1112485825
# 98          98       1     3000     3.5  1112484569
# 99          99       1     3030     3.0  1112484548
#
# [100 rows x 5 columns]

# %%
df
# Out:
#     Unnamed:-0  userId  movieId  rating   timestamp
# 0            0       1        2     3.5  1112486027
# 1            1       1       29     3.5  1112484676
# 2            2       1       32     3.5  1112484819
# 3            3       1       47     3.5  1112484727
# 4            4       1       50     3.5  1112484580
# ..         ...     ...      ...     ...         ...
# 95          95       1     2947     3.5  1112485580
# 96          96       1     2959     4.0  1094785698
# 97          97       1     2968     4.0  1112485825
# 98          98       1     3000     3.5  1112484569
# 99          99       1     3030     3.0  1112484548
#
# [100 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['Unnamed:-0', 'userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
df
# Out:
#     index1  userId  movieId  rating   timestamp
# 0        0       1        2     3.5  1112486027
# 1        1       1       29     3.5  1112484676
# 2        2       1       32     3.5  1112484819
# 3        3       1       47     3.5  1112484727
# 4        4       1       50     3.5  1112484580
# ..     ...     ...      ...     ...         ...
# 95      95       1     2947     3.5  1112485580
# 96      96       1     2959     4.0  1094785698
# 97      97       1     2968     4.0  1112485825
# 98      98       1     3000     3.5  1112484569
# 99      99       1     3030     3.0  1112484548
#
# [100 rows x 5 columns]

# %%
df.iloc[5,3]
# Out:
# 3.5

# %%
df.loc[2,"userId"]=20

# %%
df
# Out:
#     index1  userId  movieId  rating   timestamp
# 0        0       1        2     3.5  1112486027
# 1        1       1       29     3.5  1112484676
# 2        2      20       32     3.5  1112484819
# 3        3       1       47     3.5  1112484727
# 4        4       1       50     3.5  1112484580
# ..     ...     ...      ...     ...         ...
# 95      95       1     2947     3.5  1112485580
# 96      96       1     2959     4.0  1094785698
# 97      97       1     2968     4.0  1112485825
# 98      98       1     3000     3.5  1112484569
# 99      99       1     3030     3.0  1112484548
#
# [100 rows x 5 columns]

# %%
df["last"]=0

# %%
df
# Out:
#     index1  userId  movieId  rating   timestamp  last
# 0        0       1        2     3.5  1112486027     0
# 1        1       1       29     3.5  1112484676     0
# 2        2      20       32     3.5  1112484819     0
# 3        3       1       47     3.5  1112484727     0
# 4        4       1       50     3.5  1112484580     0
# ..     ...     ...      ...     ...         ...   ...
# 95      95       1     2947     3.5  1112485580     0
# 96      96       1     2959     4.0  1094785698     0
# 97      97       1     2968     4.0  1112485825     0
# 98      98       1     3000     3.5  1112484569     0
# 99      99       1     3030     3.0  1112484548     0
#
# [100 rows x 6 columns]

# %%
df
# Out:
#     index1  userId  movieId  rating   timestamp  last
# 0        0       1        2     3.5  1112486027     0
# 1        1       1       29     3.5  1112484676     0
# 2        2      20       32     3.5  1112484819     0
# 3        3       1       47     3.5  1112484727     0
# 4        4       1       50     3.5  1112484580     0
# ..     ...     ...      ...     ...         ...   ...
# 95      95       1     2947     3.5  1112485580     0
# 96      96       1     2959     4.0  1094785698     0
# 97      97       1     2968     4.0  1112485825     0
# 98      98       1     3000     3.5  1112484569     0
# 99      99       1     3030     3.0  1112484548     0
#
# [100 rows x 6 columns]

# %%
df.drop(index=5)
# Out:
#     index1  userId  movieId  rating   timestamp  last
# 0        0       1        2     3.5  1112486027     0
# 1        1       1       29     3.5  1112484676     0
# 2        2      20       32     3.5  1112484819     0
# 3        3       1       47     3.5  1112484727     0
# 4        4       1       50     3.5  1112484580     0
# ..     ...     ...      ...     ...         ...   ...
# 95      95       1     2947     3.5  1112485580     0
# 96      96       1     2959     4.0  1094785698     0
# 97      97       1     2968     4.0  1112485825     0
# 98      98       1     3000     3.5  1112484569     0
# 99      99       1     3030     3.0  1112484548     0
#
# [99 rows x 6 columns]

# %%
df.head()
# Out:
#    index1  userId  movieId  rating   timestamp  last
# 0       0       1        2     3.5  1112486027     0
# 1       1       1       29     3.5  1112484676     0
# 2       2      20       32     3.5  1112484819     0
# 3       3       1       47     3.5  1112484727     0
# 4       4       1       50     3.5  1112484580     0

# %%
df.drop(df["last"])
# Out:
#     index1  userId  movieId  rating   timestamp  last
# 1        1       1       29     3.5  1112484676     0
# 2        2      20       32     3.5  1112484819     0
# 3        3       1       47     3.5  1112484727     0
# 4        4       1       50     3.5  1112484580     0
# 5        5       1      112     3.5  1094785740     0
# ..     ...     ...      ...     ...         ...   ...
# 95      95       1     2947     3.5  1112485580     0
# 96      96       1     2959     4.0  1094785698     0
# 97      97       1     2968     4.0  1112485825     0
# 98      98       1     3000     3.5  1112484569     0
# 99      99       1     3030     3.0  1112484548     0
#
# [99 rows x 6 columns]

# %% [markdown]
# ## Sorting

# %%
df.sort_values(by="rating")
# Out:
#     index1  userId  movieId  rating   timestamp  last
# 99      99       1     3030     3.0  1112484548     0
# 41      41       1     1243     3.0  1112485567     0
# 51      51       1     1304     3.0  1094785720     0
# 57      57       1     1370     3.0  1094785764     0
# 60      60       1     1525     3.0  1112486150     0
# ..     ...     ...      ...     ...         ...   ...
# 70      70       1     2118     4.0  1094786092     0
# 53      53       1     1333     4.0  1112484990     0
# 49      49       1     1278     4.0  1094785986     0
# 30      30       1     1196     4.5  1112484742     0
# 31      31       1     1198     4.5  1112484624     0
#
# [100 rows x 6 columns]

# %%
df.sort_index(ascending=False)
# Out:
#     index1  userId  movieId  rating   timestamp  last
# 99      99       1     3030     3.0  1112484548     0
# 98      98       1     3000     3.5  1112484569     0
# 97      97       1     2968     4.0  1112485825     0
# 96      96       1     2959     4.0  1094785698     0
# 95      95       1     2947     3.5  1112485580     0
# ..     ...     ...      ...     ...         ...   ...
# 4        4       1       50     3.5  1112484580     0
# 3        3       1       47     3.5  1112484727     0
# 2        2      20       32     3.5  1112484819     0
# 1        1       1       29     3.5  1112484676     0
# 0        0       1        2     3.5  1112486027     0
#
# [100 rows x 6 columns]

# %%
df.shape
# Out:
# (100, 6)

# %%
df["rating"].sort_values()
# Out:
# 99    3.0
# 41    3.0
# 51    3.0
# 57    3.0
# 60    3.0
#      ...
# 70    4.0
# 53    4.0
# 49    4.0
# 30    4.5
# 31    4.5
# Name: rating, Length: 100, dtype: float64

# %% [markdown]
# ## Cleaning Data

# %%
df.isnull().sum()
# Out:
# index1       0
# userId       0
# movieId      0
# rating       0
# timestamp    0
# last         0
# dtype: int64

# %%
df.dropna()
# Out:
#     index1  userId  movieId  rating   timestamp  last
# 0        0       1        2     3.5  1112486027     0
# 1        1       1       29     3.5  1112484676     0
# 2        2      20       32     3.5  1112484819     0
# 3        3       1       47     3.5  1112484727     0
# 4        4       1       50     3.5  1112484580     0
# ..     ...     ...      ...     ...         ...   ...
# 95      95       1     2947     3.5  1112485580     0
# 96      96       1     2959     4.0  1094785698     0
# 97      97       1     2968     4.0  1112485825     0
# 98      98       1     3000     3.5  1112484569     0
# 99      99       1     3030     3.0  1112484548     0
#
# [100 rows x 6 columns]

# %%
df.dropna(inplace=True)

# %%
df.iloc[2,3]
# Out:
# 3.5

# %%
df.loc[2,"rating"]=" "

# %%
df.head()
# Out:
#    index1  userId  movieId rating   timestamp  last
# 0       0       1        2    3.5  1112486027     0
# 1       1       1       29    3.5  1112484676     0
# 2       2      20       32         1112484819     0
# 3       3       1       47    3.5  1112484727     0
# 4       4       1       50    3.5  1112484580     0

# %%
df.isnull().sum()
# Out:
# index1       0
# userId       0
# movieId      0
# rating       0
# timestamp    0
# last         0
# dtype: int64

# %%
df.to_csv("ratings.csv")

# %%
df
# Out:
#     index1  userId  movieId rating   timestamp  last
# 0        0       1        2    3.5  1112486027     0
# 1        1       1       29    3.5  1112484676     0
# 2        2      20       32         1112484819     0
# 3        3       1       47    3.5  1112484727     0
# 4        4       1       50    3.5  1112484580     0
# ..     ...     ...      ...    ...         ...   ...
# 95      95       1     2947    3.5  1112485580     0
# 96      96       1     2959    4.0  1094785698     0
# 97      97       1     2968    4.0  1112485825     0
# 98      98       1     3000    3.5  1112484569     0
# 99      99       1     3030    3.0  1112484548     0
#
# [100 rows x 6 columns]

# %%
df.drop(index=2)
# Out:
#     index1  userId  movieId rating   timestamp  last
# 0        0       1        2    3.5  1112486027     0
# 1        1       1       29    3.5  1112484676     0
# 3        3       1       47    3.5  1112484727     0
# 4        4       1       50    3.5  1112484580     0
# 5        5       1      112    3.5  1094785740     0
# ..     ...     ...      ...    ...         ...   ...
# 95      95       1     2947    3.5  1112485580     0
# 96      96       1     2959    4.0  1094785698     0
# 97      97       1     2968    4.0  1112485825     0
# 98      98       1     3000    3.5  1112484569     0
# 99      99       1     3030    3.0  1112484548     0
#
# [99 rows x 6 columns]
